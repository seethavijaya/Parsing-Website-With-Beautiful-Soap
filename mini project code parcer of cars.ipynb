# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %%
website = 'https://www.cars.com/shopping/results/?stock_type=cpo&makes%5B%5D=mercedes_benz&models%5B%5D=&list_price_max=&maximum_distance'

# %%
response=requests.get(website)
response.status_code
# Out:
# 200

# %%
soup = BeautifulSoup(response.content, 'html.parser')

# %%
results = soup.find_all('div', {'class' : 'vehicle-card'})

# %%
len(results)
# Out:
# 21

# %%
#carname
results[0].find('h2').get_text()
# Out:
# '2021 Mercedes-Benz AMG GT 63 4-Door'

# %%
#mileage
results[0].find('div', {'class':'mileage'}).get_text()
# Out:
# '11,016 mi.'

# %%
#price
results[0].find('span', {'class':'primary-price'}).get_text()
# Out:
# '$119,900'

# %%
#rating
results[0].find('span', {'class':'sds-rating__count'}).get_text()
# Out:
# '4.2'

# %%
#review count
results[0].find('span', {'class':'sds-rating__link'}).get_text()
# Out:
# '(1,797 reviews)'

# %%
#dealer name
results[0].find('div', {'class':'dealer-name'}).get_text().strip()
# Out:
# 'Mercedes-Benz of Wilmington'

# %%
name = []
mileage = []
price = []
dealer_name = []
rating = []
review_count = []
dealer_name = []

for result in results:
    
    # name
    try:
        name.append(result.find('h2').get_text()) 
    except:
        name.append('n/a')
    
    # mileage
    try:
        mileage.append(result.find('div', {'class':'mileage'}).get_text())
    except:
        mileage.append('n/a')
        
    #price 
    try:
        price.append(result.find('span', {'class':'primary-price'}).get_text())
    except:
        price.append('n/a')
        
    # rating
    try:
        rating.append(result.find('span', {'class':'sds-rating__count'}).get_text())
    except:
        rating.append('n/a')
    
    # review_count
    try:
        review_count.append(result.find('span', {'class':'sds-rating__link'}).get_text())
    except:
        review_count.append('n/a')
        
    # dealer_name
    try:
        dealer_name.append(result.find('div', {'class':'dealer-name'}).get_text().strip())
    except:
        dealer_name.append('n/a')

# %%
# dictionary
car_dealer = pd.DataFrame({'Name': name, 'Mileage':mileage, 'Dealer Name':dealer_name,
                                'Rating': rating, 'Review Count': review_count, 'Price': price})

# %%
car_dealer
# Out:
#                                          Name     Mileage  \
# 0         2021 Mercedes-Benz AMG GT 63 4-Door  11,016 mi.
# 1        2021 Mercedes-Benz AMG E 63 S 4MATIC  26,462 mi.
# 2           2021 Mercedes-Benz AMG GT 43 Base  36,896 mi.
# 3     2023 Mercedes-Benz AMG C 43 Base 4MATIC   2,423 mi.
# 4          2023 Mercedes-Benz AMG GLE 53 Base  15,177 mi.
# 5      2022 Mercedes-Benz GLE 350 Base 4MATIC  26,743 mi.
# 6      2024 Mercedes-Benz GLE 350 Base 4MATIC   1,693 mi.
# 7           2024 Mercedes-Benz GLE 450 4MATIC   3,209 mi.
# 8           2022 Mercedes-Benz AMG GT 53 Base   6,715 mi.
# 9            2020 Mercedes-Benz C-Class C 300  65,935 mi.
# 10           2019 Mercedes-Benz E-Class E 300  20,864 mi.
# 11          2024 Mercedes-Benz GLE 450 4MATIC   5,453 mi.
# 4          2023 Mercedes-Benz AMG GLE 53 Base  15,177 mi.
# 5      2022 Mercedes-Benz GLE 350 Base 4MATIC  26,743 mi.
# 6      2024 Mercedes-Benz GLE 350 Base 4MATIC   1,693 mi.
# 7           2024 Mercedes-Benz GLE 450 4MATIC   3,209 mi.
# 8           2022 Mercedes-Benz AMG GT 53 Base   6,715 mi.
# 9            2020 Mercedes-Benz C-Class C 300  65,935 mi.
# 10           2019 Mercedes-Benz E-Class E 300  20,864 mi.
# 11          2024 Mercedes-Benz GLE 450 4MATIC   5,453 mi.
# 12    2021 Mercedes-Benz E-Class E 350 4MATIC  43,860 mi.
# 13          2021 Mercedes-Benz GLS 450 4MATIC  45,480 mi.
# 14     2019 Mercedes-Benz GLC 300 Base 4MATIC  18,634 mi.
# 15  2023 Mercedes-Benz AMG GLS 63 Base 4MATIC   8,519 mi.
# 16          2021 Mercedes-Benz GLS 450 4MATIC  44,000 mi.
# 17           2020 Mercedes-Benz S-Class S 450  38,752 mi.
# 18           2020 Mercedes-Benz S-Class S 450  23,232 mi.
# 19     2023 Mercedes-Benz EQS 580 Base 4MATIC   6,776 mi.
# 20           2018 Mercedes-Benz S-Class S 560  58,846 mi.
#
#                           Dealer Name Rating Review Count     Price
# 0         Mercedes-Benz of Wilmington    4.2       1,797   $119,900
# 1         Mercedes-Benz of Louisville    4.5         991    $94,754
# 2      Mercedes-Benz of North Olmsted    4.8       1,538    $67,923
# 3               Jackie Cooper Imports    4.9       4,477    $62,000
# 4         Mercedes-Benz of Tuscaloosa    n/a          15    $73,972
# 5                Euro Motorcars Devon    4.1         344    $55,389
# 6    Mercedes-Benz of Fort Washington    4.6       3,138    $67,254
# 7            Mercedes-Benz Doylestown    4.3          55    $74,118
# 8            Mercedes-Benz of Jackson    4.1         821    $90,325
# 9            Mercedes-Benz of Jackson    4.1         821    $24,345
# 10  Mercedes-Benz of Orange County NY    4.5         523    $35,491
# 11  Mercedes-Benz of Orange County NY    4.5         523    $76,987
# 12      Mercedes-Benz of White Plains    4.3       1,647    $37,534
# 13       Mercedes-Benz of Springfield    4.6         110    $54,497
# 14       Mercedes-Benz of Springfield    4.6         110    $29,644
# 15  Mercedes-Benz of Houston Greenway    4.7       2,899   $136,450
# 16      Mercedes-Benz of West Houston    4.6          76    $55,993
# 17      Mercedes-Benz of West Houston    4.6          76    $52,994
# 18      Mercedes-Benz of West Houston    4.6          76    $54,996
# 19            Mercedes-Benz of Naples    4.8       1,559    $87,487
# 20     Mercedes-Benz of Coconut Creek    4.5       1,475    $44,995

# %%
car_dealer.to_excel('car_dealer_single_page.xlsx', index=False)

# %%
# write into csv
cars_df = pd.DataFrame(car_dealer)
csv_file_name = 'car_dealer_single_page.csv'
cars_df.to_csv(csv_file_name, index=False)
